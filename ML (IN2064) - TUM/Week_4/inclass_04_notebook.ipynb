# %%
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
sns.set(palette='deep', style='whitegrid')

from sklearn.datasets import load_boston
from sklearn.linear_model import Lasso, Ridge, ElasticNet, LinearRegression
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# Install __[ipywidgets](https://github.com/jupyter-widgets/ipywidgets/blob/master/README.md#install)__ .
#
# Make sure you run
#
#     jupyter nbextension enable --py --sys-prefix widgetsnbextension
#
# in your terminal for the interactive plots to work

# %% [markdown]
# # How changing the polynomial degree $M$ corresponds to the bias-variance tradeoff

# %% [markdown]
# ### What to talk about
# * Bias variance tradeoff caused by higher/lower polynomial degrees

# %%
# %matplotlib notebook
plt.figure(figsize=[10, 6])
def plot_fit(degree=1, seed=1):
    plt.cla()
    n_samples = 30

    np.random.seed(seed)
    true_fun = lambda X: np.sin(np.pi * X)
    X = np.sort(np.random.uniform(high=2, size=n_samples))
    y = true_fun(X) + np.random.randn(n_samples) * 0.1
    
    polynomial_features = PolynomialFeatures(degree=degree, include_bias=False)
    linear_regression = LinearRegression()
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    pipeline.fit(X[:, np.newaxis], y)

    X_test = np.linspace(0, 2, 100)
    plt.plot(X_test, true_fun(X_test), label="True function")
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]), label="Model")
    plt.scatter(X, y, label="Samples")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 2))
    plt.ylim((-2, 2))
    plt.legend(loc=1)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
interact(plot_fit, degree=(1, 30, 1), seed=(1, 10, 1));
# Out:
# interactive(children=(IntSlider(value=1, description='degree', max=30, min=1), IntSlider(value=1, description=…

# %% [markdown]
# # How changing the regularization strength $\lambda$ corresponds to the bias-variance tradeoff

# %% [markdown]
# ### What to talk about
# * Bias variance tradeoff caused by higher/lower regularization strength

# %%
# %matplotlib notebook
plt.figure(figsize=[10, 6])
def ridge_polynomial(log_lambda=0, seed=1):
    plt.cla()
    n_samples = 20

    true_fun = lambda X: np.sin(np.pi * X)
    np.random.seed(seed)
    X = np.sort(np.random.uniform(high=2, size=n_samples))
    y = true_fun(X) + np.random.randn(n_samples) * 0.1
    

    polynomial_features = PolynomialFeatures(degree=15, include_bias=False)
    linear_regression = Ridge(alpha=np.power(10, log_lambda))
    pipeline = Pipeline([("polynomial_features", polynomial_features),
                         ("linear_regression", linear_regression)])
    pipeline.fit(X[:, np.newaxis], y)

    X_test = np.linspace(0, 2, 100)
    plt.plot(X_test, true_fun(X_test), label="True function")
    plt.plot(X_test, pipeline.predict(X_test[:, np.newaxis]), label="Model")
    plt.scatter(X, y, label="Samples")
    plt.xlabel("x")
    plt.ylabel("y")
    plt.xlim((0, 2))
    plt.ylim((-2, 2))
    plt.legend(loc=1)
    plt.show()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
ridge_polynomial(log_lambda=0, seed=1)

# %%
interact(ridge_polynomial, log_lambda=(-15, 10, 1.0), seed=(1, 10, 1));
# Out:
# interactive(children=(FloatSlider(value=0.0, description='log_lambda', max=10.0, min=-15.0, step=1.0), IntSlid…

# %% [markdown]
# # Shrinkage with $L_2$ (ridge) and $L_1$ (lasso) regularization

# %% [markdown]
# ### What to talk about
# * Other types of regularization are possible, not necessarily $L_2$, any $L_p$ norm for $p \geq 1$ can be used.
# * Using $0 < p < 1$ leads to nonconvex objective.
# * Using $L_0$ pseudonorm is impossible to optimize with tools discussed in this course, this is called *Compressed sensing* -> entire research discipline.
# * $L_2$ is called **Ridge** leads to smaller values of $\mathbf{w}$ overall, but no entries are equal to 0. Also easier to optimize.
# * $L_1$ is called **Lasso**, leads to sparse $\mathbf{w}$ (lots of entries are equal to 0)
# * You can combine both penalties -> Elastic net
# * http://www.ds100.org/sp17/assets/notebooks/linear_regression/norm_balls.png
# * There exist other regularization schemes, doesn't have to be weight penalty. In general, regularization - decreasing model capacity / increasing bias / reducing variance.

# %%
data = load_boston()
X = data['data']
y = data['target']
names = data['feature_names']

# %%
lambdas = np.logspace(-4, 4, num=100)
# Ridge regression
coefs_ridge = []
for a in lambdas:
    ridge = ElasticNet(alpha=a, l1_ratio=0)
    ridge.fit(X, y)
    coefs_ridge.append(ridge.coef_)
coefs_ridge = np.array(coefs_ridge)

# Lasso
coefs_lasso = []
for a in lambdas:
    lasso = ElasticNet(alpha=a, l1_ratio=1)
    lasso.fit(X, y)
    coefs_lasso.append(lasso.coef_)
coefs_lasso = np.array(coefs_lasso)
# Out:
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5547.761568118947, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5549.41284196829, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5551.375866718141, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5553.703573224439, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5556.455437197987, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5559.697284596212, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5563.500611887753, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5567.941258489778, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5573.097269806021, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5579.045823454808, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5585.8591749100315, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5593.599726010505, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5602.314534631483, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5612.0298495713505, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5622.746524360393, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5634.437357669682, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5647.0474277567555, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5660.498249907288, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5674.69606607116, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5689.543850663386, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5704.9558614302405, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5720.873002761695, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5737.277082102297, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5754.202284804561, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5771.742774232146, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5790.056041959472, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5809.362271770902, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5829.940392330811, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5852.12163223007, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5876.281302102461, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5902.829301883405, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5932.199581252064, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 5964.838545275331, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6001.1922586421715, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6041.692323917543, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6086.740560041088, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6136.69313717448, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6191.845611887138, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6252.421197104619, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6318.565278679142, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6390.349240737467, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6467.785736931987, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6550.855578865492, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6639.543776597044, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6733.879730171066, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6833.9750402916225, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 6940.052521905289, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7052.461828063881, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7171.6800587407915, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7298.298905949459, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7433.002370852776, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7576.540329020821, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7729.703095025364, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7893.300815018681, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8068.149251149071, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8255.060574128827, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8454.834514642702, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8668.24228650206, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 8895.99405277814, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9138.681417507241, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9396.690189795012, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9670.085401166432, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 9958.47921197805, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10260.90102766128, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10575.695480657363, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 10900.475558526414, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11232.153391468286, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11567.059815927205, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 11901.147610600023, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12230.256067895096, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12550.401125520599, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12858.049684032485, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13150.340574430522, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13425.226407316364, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13681.52636762165, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 13918.895387981676, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14137.726534266167, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14339.009302739207, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14524.167189366577, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14694.894883336085, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14853.010642566906, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15000.334388689937, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15138.59770537073, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15269.388437554418, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15394.129694079078, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15514.090346523597, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15630.421400414663, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15744.210096857594, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15856.54181545971, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 15968.559350865846, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16081.510154535586, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16196.77438611912, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16315.869409399762, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16440.428914197193, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16572.156634714334, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16712.75563068408, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16863.834735355365, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17026.794775519436, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17202.69925363851, tolerance: 4.271629541501976
#   positive)
# /home/x/anaconda3/envs/rl/lib/python3.7/site-packages/sklearn/linear_model/_coordinate_descent.py:532: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 17392.137739500682, tolerance: 4.271629541501976
#   positive)

# %%
# %matplotlib inline
sns.set(font_scale=2, style='whitegrid')
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=[30, 15])
# Plot ridge
for i in range(13):
    mask = coefs_ridge[:, i] != 0
    ax1.semilogx(lambdas[mask], coefs_ridge[:, i][mask], label=names[i])
ax1.set_xlabel('log $\lambda$ ')
ax1.set_ylabel('Coefficients values')
ax1.set_title('Ridge regression ($L_2$)')
ax1.set_xlim(right=1e4)
ax1.legend()

# Plot lasso
for i in range(13):
    # don't plot the parts where the coefficient is equal to 0
    mask = coefs_lasso[:, i] != 0
    mask[np.where(~mask)[0][0]] = True  
    ax2.semilogx(lambdas[mask], coefs_lasso[:, i][mask], label=names[i])
ax2.set_xlabel('log $\lambda$ ')
ax2.set_title('Lasso ($L_1$)')
ax2.set_xlim(right=1e4)
ax2.legend()
plt.show()

# %% [markdown]
# ### Interpretation of the plots
# The plots show how values of model weights change as regularization scale increases.
#
# In the plots we confirm these facts:
# * $L_2$ leads to smaller values of $\mathbf{w}$ overall, but no entries are equal to 0.
# * $L_1$ leads to sparse $\mathbf{w}$ (lots of entries are equal to 0 as log lambda increases).
# * More on weights regularization in Section 3.4 of https://web.stanford.edu/~hastie/Papers/ESLII.pdf
